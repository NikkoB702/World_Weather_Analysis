# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 761

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
import config

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
        # Append the city information into the city_data list
        
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
    
    # If an error is experienced, skip the city
    
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | khatanga
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | port hardy
# Processing Record 4 of Set 1 | diffa
# Processing Record 5 of Set 1 | hithadhoo
# Processing Record 6 of Set 1 | cayenne
# Processing Record 7 of Set 1 | aksu
# Processing Record 8 of Set 1 | soc trang
# Processing Record 9 of Set 1 | arraial do cabo
# Processing Record 10 of Set 1 | sao joao da barra
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | henties bay
# Processing Record 13 of Set 1 | tasiilaq
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | lebu
# Processing Record 16 of Set 1 | port hedland
# Processing Record 17 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | vardo
# Processing Record 21 of Set 1 | port hawkesbury
# Processing Record 22 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | meadow lake
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | lac du bonnet
# Processing Record 30 of Set 1 | baruun-urt
# Processing Record 31 of Set 1 | chuy
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | sitka
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | cam pha
# City not found. Skipping...
# Processing Record 36 of Set 1 | bambanglipuro
# Processing Record 37 of Set 1 | chokurdakh
# Processing Record 38 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 39 of Set 1 | ketchikan
# Processing Record 40 of Set 1 | torbay
# Processing Record 41 of Set 1 | kahului
# Processing Record 42 of Set 1 | zeya
# Processing Record 43 of Set 1 | half moon bay
# Processing Record 44 of Set 1 | grindavik
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | namibe
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | ribeira grande
# Processing Record 1 of Set 2 | puerto escondido
# Processing Record 2 of Set 2 | mount isa
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | upernavik
# Processing Record 5 of Set 2 | asau
# Processing Record 6 of Set 2 | nazareno etla
# Processing Record 7 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 8 of Set 2 | aliwal north
# Processing Record 9 of Set 2 | pemba
# Processing Record 10 of Set 2 | ahome
# Processing Record 11 of Set 2 | matagami
# Processing Record 12 of Set 2 | severo-kurilsk
# Processing Record 13 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 2 | qaanaaq
# Processing Record 15 of Set 2 | kailua
# Processing Record 16 of Set 2 | barrow
# Processing Record 17 of Set 2 | tuatapere
# Processing Record 18 of Set 2 | busselton
# Processing Record 19 of Set 2 | yellowknife
# Processing Record 20 of Set 2 | astipalaia
# City not found. Skipping...
# Processing Record 21 of Set 2 | cherskiy
# Processing Record 22 of Set 2 | jaciara
# Processing Record 23 of Set 2 | vestmannaeyjar
# Processing Record 24 of Set 2 | flinders
# Processing Record 25 of Set 2 | makakilo city
# Processing Record 26 of Set 2 | pangnirtung
# Processing Record 27 of Set 2 | roma
# Processing Record 28 of Set 2 | nandi
# Processing Record 29 of Set 2 | novo aripuana
# Processing Record 30 of Set 2 | fortuna
# Processing Record 31 of Set 2 | tuktoyaktuk
# Processing Record 32 of Set 2 | bilma
# Processing Record 33 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 34 of Set 2 | magnolia
# Processing Record 35 of Set 2 | unhel
# Processing Record 36 of Set 2 | alofi
# Processing Record 37 of Set 2 | jimenez
# Processing Record 38 of Set 2 | neiafu
# Processing Record 39 of Set 2 | bredasdorp
# Processing Record 40 of Set 2 | kostomuksha
# Processing Record 41 of Set 2 | nabire
# Processing Record 42 of Set 2 | batemans bay
# Processing Record 43 of Set 2 | thompson
# Processing Record 44 of Set 2 | vieques
# Processing Record 45 of Set 2 | balimo
# City not found. Skipping...
# Processing Record 46 of Set 2 | hermanus
# Processing Record 47 of Set 2 | duz
# City not found. Skipping...
# Processing Record 48 of Set 2 | cabo san lucas
# Processing Record 49 of Set 2 | tiksi
# Processing Record 50 of Set 2 | aykhal
# Processing Record 1 of Set 3 | shalinskoye
# Processing Record 2 of Set 3 | basco
# Processing Record 3 of Set 3 | sorland
# Processing Record 4 of Set 3 | waipawa
# Processing Record 5 of Set 3 | kloulklubed
# Processing Record 6 of Set 3 | saint-augustin
# Processing Record 7 of Set 3 | banjarmasin
# Processing Record 8 of Set 3 | mar del plata
# Processing Record 9 of Set 3 | meiganga
# Processing Record 10 of Set 3 | leshukonskoye
# Processing Record 11 of Set 3 | airai
# Processing Record 12 of Set 3 | taoudenni
# Processing Record 13 of Set 3 | atasu
# Processing Record 14 of Set 3 | edd
# Processing Record 15 of Set 3 | geraldton
# Processing Record 16 of Set 3 | kaitangata
# Processing Record 17 of Set 3 | manado
# Processing Record 18 of Set 3 | mahebourg
# Processing Record 19 of Set 3 | labelle
# Processing Record 20 of Set 3 | mackenzie
# Processing Record 21 of Set 3 | ilulissat
# Processing Record 22 of Set 3 | port elizabeth
# Processing Record 23 of Set 3 | georgetown
# Processing Record 24 of Set 3 | ozgon
# City not found. Skipping...
# Processing Record 25 of Set 3 | koath
# Processing Record 26 of Set 3 | belmonte
# Processing Record 27 of Set 3 | lazaro cardenas
# Processing Record 28 of Set 3 | jurbarkas
# Processing Record 29 of Set 3 | jamestown
# Processing Record 30 of Set 3 | naze
# Processing Record 31 of Set 3 | esperance
# Processing Record 32 of Set 3 | touros
# Processing Record 33 of Set 3 | dikson
# Processing Record 34 of Set 3 | nizwa
# Processing Record 35 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 3 | barvinkove
# Processing Record 37 of Set 3 | vao
# Processing Record 38 of Set 3 | grand gaube
# Processing Record 39 of Set 3 | salalah
# Processing Record 40 of Set 3 | dovhe
# Processing Record 41 of Set 3 | kruisfontein
# Processing Record 42 of Set 3 | yeppoon
# Processing Record 43 of Set 3 | katsuura
# Processing Record 44 of Set 3 | sao jose da coroa grande
# Processing Record 45 of Set 3 | avarua
# Processing Record 46 of Set 3 | kuminskiy
# Processing Record 47 of Set 3 | altay
# Processing Record 48 of Set 3 | kamenka
# Processing Record 49 of Set 3 | saldanha
# Processing Record 50 of Set 3 | nagai
# Processing Record 1 of Set 4 | saint-joseph
# Processing Record 2 of Set 4 | college
# Processing Record 3 of Set 4 | stornoway
# Processing Record 4 of Set 4 | muros
# Processing Record 5 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 6 of Set 4 | novobirilyussy
# Processing Record 7 of Set 4 | chas
# Processing Record 8 of Set 4 | tabulbah
# City not found. Skipping...
# Processing Record 9 of Set 4 | urumqi
# Processing Record 10 of Set 4 | sioux lookout
# Processing Record 11 of Set 4 | azanja
# Processing Record 12 of Set 4 | tahta
# Processing Record 13 of Set 4 | faanui
# Processing Record 14 of Set 4 | sinop
# Processing Record 15 of Set 4 | senador jose porfirio
# Processing Record 16 of Set 4 | meulaboh
# Processing Record 17 of Set 4 | castro
# Processing Record 18 of Set 4 | sao filipe
# Processing Record 19 of Set 4 | caravelas
# Processing Record 20 of Set 4 | tazmalt
# Processing Record 21 of Set 4 | dingle
# Processing Record 22 of Set 4 | luquillo
# Processing Record 23 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 4 | broken hill
# Processing Record 25 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 26 of Set 4 | betanzos
# Processing Record 27 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 28 of Set 4 | walvis bay
# Processing Record 29 of Set 4 | yulara
# Processing Record 30 of Set 4 | wattegama
# Processing Record 31 of Set 4 | faya
# Processing Record 32 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 4 | praya
# Processing Record 34 of Set 4 | provideniya
# Processing Record 35 of Set 4 | princeton
# Processing Record 36 of Set 4 | bambous virieux
# Processing Record 37 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 38 of Set 4 | banjar
# Processing Record 39 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 4 | tupancireta
# Processing Record 41 of Set 4 | new norfolk
# Processing Record 42 of Set 4 | noumea
# Processing Record 43 of Set 4 | saint george
# Processing Record 44 of Set 4 | thomaston
# Processing Record 45 of Set 4 | petit goave
# Processing Record 46 of Set 4 | sistranda
# Processing Record 47 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 4 | maceio
# Processing Record 49 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 4 | homer
# Processing Record 1 of Set 5 | jaszalsoszentgyorgy
# Processing Record 2 of Set 5 | hasaki
# Processing Record 3 of Set 5 | lorengau
# Processing Record 4 of Set 5 | bolobo
# Processing Record 5 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 5 | leningradskiy
# Processing Record 7 of Set 5 | clyde river
# Processing Record 8 of Set 5 | yinchuan
# Processing Record 9 of Set 5 | jaguarari
# Processing Record 10 of Set 5 | klaksvik
# Processing Record 11 of Set 5 | vostok
# Processing Record 12 of Set 5 | hilo
# Processing Record 13 of Set 5 | chifeng
# Processing Record 14 of Set 5 | deputatskiy
# Processing Record 15 of Set 5 | vung tau
# Processing Record 16 of Set 5 | san lorenzo de el escorial
# Processing Record 17 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 5 | lasa
# Processing Record 19 of Set 5 | kungalv
# Processing Record 20 of Set 5 | portland
# Processing Record 21 of Set 5 | saint-pierre
# Processing Record 22 of Set 5 | nikolskoye
# Processing Record 23 of Set 5 | tunduru
# City not found. Skipping...
# Processing Record 24 of Set 5 | krasnyye baki
# Processing Record 25 of Set 5 | havre-saint-pierre
# Processing Record 26 of Set 5 | hami
# Processing Record 27 of Set 5 | utica
# Processing Record 28 of Set 5 | barentu
# Processing Record 29 of Set 5 | east london
# Processing Record 30 of Set 5 | klyuchi
# Processing Record 31 of Set 5 | gwadar
# Processing Record 32 of Set 5 | los llanos de aridane
# Processing Record 33 of Set 5 | mayumba
# Processing Record 34 of Set 5 | bossembele
# City not found. Skipping...
# Processing Record 35 of Set 5 | vanimo
# Processing Record 36 of Set 5 | yankton
# Processing Record 37 of Set 5 | san ramon de la nueva oran
# Processing Record 38 of Set 5 | shimoda
# Processing Record 39 of Set 5 | tura
# Processing Record 40 of Set 5 | mayo
# Processing Record 41 of Set 5 | pevek
# Processing Record 42 of Set 5 | ilinskiy
# Processing Record 43 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 5 | hvide sande
# Processing Record 46 of Set 5 | victoria
# Processing Record 47 of Set 5 | coquimbo
# Processing Record 48 of Set 5 | bairiki
# Processing Record 49 of Set 5 | visnes
# Processing Record 50 of Set 5 | talnakh
# Processing Record 1 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 6 | lompoc
# Processing Record 3 of Set 6 | save
# Processing Record 4 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 5 of Set 6 | ambunti
# Processing Record 6 of Set 6 | narsaq
# Processing Record 7 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 6 | cootamundra
# Processing Record 9 of Set 6 | taltal
# Processing Record 10 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 11 of Set 6 | umm kaddadah
# Processing Record 12 of Set 6 | oranjemund
# Processing Record 13 of Set 6 | komsomolskiy
# Processing Record 14 of Set 6 | amahai
# Processing Record 15 of Set 6 | chhapar
# Processing Record 16 of Set 6 | ust-koksa
# Processing Record 17 of Set 6 | luderitz
# Processing Record 18 of Set 6 | neuquen
# Processing Record 19 of Set 6 | kodiak
# Processing Record 20 of Set 6 | balkhash
# Processing Record 21 of Set 6 | jasper
# Processing Record 22 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 23 of Set 6 | juneau
# Processing Record 24 of Set 6 | srednekolymsk
# Processing Record 25 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 6 | kayerkan
# Processing Record 27 of Set 6 | riyadh
# Processing Record 28 of Set 6 | jumla
# Processing Record 29 of Set 6 | simoes
# Processing Record 30 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 6 | marzuq
# Processing Record 32 of Set 6 | saint-philippe
# Processing Record 33 of Set 6 | ocos
# Processing Record 34 of Set 6 | kutum
# Processing Record 35 of Set 6 | hervey bay
# Processing Record 36 of Set 6 | pereslavl-zalesskiy
# Processing Record 37 of Set 6 | port lincoln
# Processing Record 38 of Set 6 | miri
# Processing Record 39 of Set 6 | ixtapa
# Processing Record 40 of Set 6 | inta
# Processing Record 41 of Set 6 | teguise
# Processing Record 42 of Set 6 | stokmarknes
# Processing Record 43 of Set 6 | yeletskiy
# City not found. Skipping...
# Processing Record 44 of Set 6 | ostrovnoy
# Processing Record 45 of Set 6 | iguape
# Processing Record 46 of Set 6 | misratah
# Processing Record 47 of Set 6 | xai-xai
# Processing Record 48 of Set 6 | kirakira
# Processing Record 49 of Set 6 | lewiston
# Processing Record 50 of Set 6 | yar-sale
# Processing Record 1 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 7 | la ligua
# Processing Record 4 of Set 7 | labuhan
# Processing Record 5 of Set 7 | pombas
# Processing Record 6 of Set 7 | nyimba
# Processing Record 7 of Set 7 | sisimiut
# Processing Record 8 of Set 7 | pimentel
# Processing Record 9 of Set 7 | cairns
# Processing Record 10 of Set 7 | canberra
# Processing Record 11 of Set 7 | rundu
# Processing Record 12 of Set 7 | abiy adi
# City not found. Skipping...
# Processing Record 13 of Set 7 | harer
# Processing Record 14 of Set 7 | medina del campo
# Processing Record 15 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 7 | dabakala
# Processing Record 17 of Set 7 | sola
# Processing Record 18 of Set 7 | shubarshi
# Processing Record 19 of Set 7 | watsa
# Processing Record 20 of Set 7 | amethi
# Processing Record 21 of Set 7 | khandbari
# Processing Record 22 of Set 7 | vila franca do campo
# Processing Record 23 of Set 7 | bud
# Processing Record 24 of Set 7 | kisangani
# Processing Record 25 of Set 7 | canton
# Processing Record 26 of Set 7 | siilinjarvi
# Processing Record 27 of Set 7 | tarancon
# Processing Record 28 of Set 7 | mackay
# Processing Record 29 of Set 7 | alice springs
# Processing Record 30 of Set 7 | shenjiamen
# Processing Record 31 of Set 7 | reconquista
# Processing Record 32 of Set 7 | male
# Processing Record 33 of Set 7 | cidreira
# Processing Record 34 of Set 7 | carnarvon
# Processing Record 35 of Set 7 | beldanga
# Processing Record 36 of Set 7 | port antonio
# Processing Record 37 of Set 7 | barra patuca
# Processing Record 38 of Set 7 | ampanihy
# Processing Record 39 of Set 7 | sencha
# Processing Record 40 of Set 7 | goiatuba
# Processing Record 41 of Set 7 | clyde
# Processing Record 42 of Set 7 | menongue
# Processing Record 43 of Set 7 | kuytun
# Processing Record 44 of Set 7 | el tigre
# Processing Record 45 of Set 7 | palmas bellas
# Processing Record 46 of Set 7 | sinnamary
# Processing Record 47 of Set 7 | maraa
# Processing Record 48 of Set 7 | kupang
# Processing Record 49 of Set 7 | burnie
# Processing Record 50 of Set 7 | adamovka
# Processing Record 1 of Set 8 | daloa
# Processing Record 2 of Set 8 | surskoye
# Processing Record 3 of Set 8 | nouadhibou
# Processing Record 4 of Set 8 | north bend
# Processing Record 5 of Set 8 | tilichiki
# Processing Record 6 of Set 8 | ancud
# Processing Record 7 of Set 8 | san patricio
# Processing Record 8 of Set 8 | seoul
# Processing Record 9 of Set 8 | morong
# Processing Record 10 of Set 8 | te anau
# Processing Record 11 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 12 of Set 8 | hambantota
# Processing Record 13 of Set 8 | tautira
# Processing Record 14 of Set 8 | muroto
# Processing Record 15 of Set 8 | kuna
# Processing Record 16 of Set 8 | arman
# Processing Record 17 of Set 8 | port augusta
# Processing Record 18 of Set 8 | panguna
# Processing Record 19 of Set 8 | wladyslawowo
# Processing Record 20 of Set 8 | smolenka
# Processing Record 21 of Set 8 | istmina
# Processing Record 22 of Set 8 | basoko
# Processing Record 23 of Set 8 | puerto montt
# Processing Record 24 of Set 8 | angoche
# Processing Record 25 of Set 8 | tarrafal
# Processing Record 26 of Set 8 | guerrero negro
# Processing Record 27 of Set 8 | saint anthony
# Processing Record 28 of Set 8 | yumen
# Processing Record 29 of Set 8 | aporawan
# City not found. Skipping...
# Processing Record 30 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 8 | show low
# Processing Record 32 of Set 8 | winneba
# Processing Record 33 of Set 8 | avera
# Processing Record 34 of Set 8 | sayyan
# Processing Record 35 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 36 of Set 8 | hovd
# Processing Record 37 of Set 8 | champerico
# Processing Record 38 of Set 8 | yaan
# Processing Record 39 of Set 8 | nanortalik
# Processing Record 40 of Set 8 | buala
# Processing Record 41 of Set 8 | herat
# Processing Record 42 of Set 8 | kyzyl-suu
# Processing Record 43 of Set 8 | cherechiu
# Processing Record 44 of Set 8 | agadez
# Processing Record 45 of Set 8 | santa fe
# Processing Record 46 of Set 8 | hedaru
# Processing Record 47 of Set 8 | suez
# Processing Record 48 of Set 8 | vaitape
# Processing Record 49 of Set 8 | weligama
# Processing Record 50 of Set 8 | samarai
# Processing Record 1 of Set 9 | hotaka
# Processing Record 2 of Set 9 | krasnoselkup
# Processing Record 3 of Set 9 | rio cuarto
# Processing Record 4 of Set 9 | handwara
# City not found. Skipping...
# Processing Record 5 of Set 9 | divnomorskoye
# Processing Record 6 of Set 9 | la ronge
# Processing Record 7 of Set 9 | tir pol
# City not found. Skipping...
# Processing Record 8 of Set 9 | longyearbyen
# Processing Record 9 of Set 9 | slave lake
# Processing Record 10 of Set 9 | tahoua
# Processing Record 11 of Set 9 | altamira
# Processing Record 12 of Set 9 | mabaruma
# Processing Record 13 of Set 9 | laguna
# Processing Record 14 of Set 9 | veraval
# Processing Record 15 of Set 9 | camacha
# Processing Record 16 of Set 9 | shimanovsk
# Processing Record 17 of Set 9 | itoman
# Processing Record 18 of Set 9 | general roca
# Processing Record 19 of Set 9 | bolshaya martynovka
# Processing Record 20 of Set 9 | sakaiminato
# Processing Record 21 of Set 9 | songjianghe
# Processing Record 22 of Set 9 | rio gallegos
# Processing Record 23 of Set 9 | villefranche-de-rouergue
# Processing Record 24 of Set 9 | sehwan
# Processing Record 25 of Set 9 | koutiala
# Processing Record 26 of Set 9 | andros town
# Processing Record 27 of Set 9 | pochutla
# Processing Record 28 of Set 9 | saveh
# Processing Record 29 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 9 | coahuayana
# Processing Record 31 of Set 9 | pedro betancourt
# Processing Record 32 of Set 9 | tutoia
# Processing Record 33 of Set 9 | gueret
# Processing Record 34 of Set 9 | albstadt
# Processing Record 35 of Set 9 | victor harbor
# Processing Record 36 of Set 9 | almeirim
# Processing Record 37 of Set 9 | worland
# Processing Record 38 of Set 9 | goianapolis
# Processing Record 39 of Set 9 | luklukan
# Processing Record 40 of Set 9 | abay
# Processing Record 41 of Set 9 | oceanside
# Processing Record 42 of Set 9 | pisco
# Processing Record 43 of Set 9 | iqaluit
# Processing Record 44 of Set 9 | bengkulu
# Processing Record 45 of Set 9 | nemuro
# Processing Record 46 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 47 of Set 9 | pandhana
# Processing Record 48 of Set 9 | cacoal
# Processing Record 49 of Set 9 | madisonville
# Processing Record 50 of Set 9 | suntar
# Processing Record 1 of Set 10 | berlevag
# Processing Record 2 of Set 10 | porosozero
# Processing Record 3 of Set 10 | isangel
# Processing Record 4 of Set 10 | mount gambier
# Processing Record 5 of Set 10 | san rafael del sur
# Processing Record 6 of Set 10 | amurzet
# Processing Record 7 of Set 10 | aviles
# Processing Record 8 of Set 10 | aasiaat
# Processing Record 9 of Set 10 | roebourne
# Processing Record 10 of Set 10 | linxia
# Processing Record 11 of Set 10 | passos
# Processing Record 12 of Set 10 | kavieng
# Processing Record 13 of Set 10 | lata
# Processing Record 14 of Set 10 | constitucion
# Processing Record 15 of Set 10 | miandrivazo
# Processing Record 16 of Set 10 | hualmay
# Processing Record 17 of Set 10 | kasongo-lunda
# Processing Record 18 of Set 10 | kampot
# Processing Record 19 of Set 10 | saint-leu
# Processing Record 20 of Set 10 | kolosovka
# Processing Record 21 of Set 10 | sibolga
# Processing Record 22 of Set 10 | bandarbeyla
# Processing Record 23 of Set 10 | ashland
# Processing Record 24 of Set 10 | krasnokholm
# Processing Record 25 of Set 10 | huilong
# Processing Record 26 of Set 10 | itambacuri
# Processing Record 27 of Set 10 | richards bay
# Processing Record 28 of Set 10 | lahij
# Processing Record 29 of Set 10 | lincoln
# Processing Record 30 of Set 10 | play cu
# City not found. Skipping...
# Processing Record 31 of Set 10 | ha tinh
# Processing Record 32 of Set 10 | chapais
# Processing Record 33 of Set 10 | kiama
# Processing Record 34 of Set 10 | padang
# Processing Record 35 of Set 10 | lavrentiya
# Processing Record 36 of Set 10 | el vigia
# Processing Record 37 of Set 10 | hirara
# Processing Record 38 of Set 10 | kavaratti
# Processing Record 39 of Set 10 | ewa beach
# Processing Record 40 of Set 10 | qaqortoq
# Processing Record 41 of Set 10 | toyooka
# Processing Record 42 of Set 10 | syrskoye
# Processing Record 43 of Set 10 | talcahuano
# Processing Record 44 of Set 10 | cepu
# Processing Record 45 of Set 10 | northam
# Processing Record 46 of Set 10 | alihe
# Processing Record 47 of Set 10 | acapulco
# Processing Record 48 of Set 10 | moissala
# Processing Record 49 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 10 | anupgarh
# Processing Record 1 of Set 11 | fairbanks
# Processing Record 2 of Set 11 | nakhon thai
# Processing Record 3 of Set 11 | dunedin
# Processing Record 4 of Set 11 | quatre cocos
# Processing Record 5 of Set 11 | george
# Processing Record 6 of Set 11 | lalpur
# Processing Record 7 of Set 11 | yerbogachen
# Processing Record 8 of Set 11 | marawi
# Processing Record 9 of Set 11 | korla
# Processing Record 10 of Set 11 | codrington
# Processing Record 11 of Set 11 | tomatlan
# Processing Record 12 of Set 11 | nyurba
# Processing Record 13 of Set 11 | aswan
# Processing Record 14 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 11 | villa carlos paz
# Processing Record 16 of Set 11 | buchanan
# Processing Record 17 of Set 11 | mardin
# Processing Record 18 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 19 of Set 11 | palmer
# Processing Record 20 of Set 11 | vila velha
# Processing Record 21 of Set 11 | pangody
# Processing Record 22 of Set 11 | shelburne
# Processing Record 23 of Set 11 | ingleside
# Processing Record 24 of Set 11 | nome
# Processing Record 25 of Set 11 | sindor
# Processing Record 26 of Set 11 | noyabrsk
# Processing Record 27 of Set 11 | lima
# Processing Record 28 of Set 11 | saint-francois
# Processing Record 29 of Set 11 | shingu
# Processing Record 30 of Set 11 | sawakin
# Processing Record 31 of Set 11 | onega
# Processing Record 32 of Set 11 | sussex
# Processing Record 33 of Set 11 | taylor
# Processing Record 34 of Set 11 | anju
# Processing Record 35 of Set 11 | santa marta
# Processing Record 36 of Set 11 | paragominas
# Processing Record 37 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 11 | tineo
# Processing Record 39 of Set 11 | puerto penasco
# Processing Record 40 of Set 11 | sabang
# Processing Record 41 of Set 11 | sangar
# Processing Record 42 of Set 11 | poli
# Processing Record 43 of Set 11 | oktyabrskoye
# Processing Record 44 of Set 11 | nouakchott
# Processing Record 45 of Set 11 | ola
# Processing Record 46 of Set 11 | clermont
# Processing Record 47 of Set 11 | stilis
# City not found. Skipping...
# Processing Record 48 of Set 11 | redmond
# Processing Record 49 of Set 11 | opuwo
# Processing Record 50 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 1 of Set 12 | belaya gora
# Processing Record 2 of Set 12 | durusu
# Processing Record 3 of Set 12 | zemio
# Processing Record 4 of Set 12 | vredendal
# Processing Record 5 of Set 12 | luanda
# Processing Record 6 of Set 12 | keningau
# Processing Record 7 of Set 12 | lerwick
# Processing Record 8 of Set 12 | mecca
# Processing Record 9 of Set 12 | mezen
# Processing Record 10 of Set 12 | dunmore east
# Processing Record 11 of Set 12 | yelatma
# Processing Record 12 of Set 12 | shvartsevskiy
# Processing Record 13 of Set 12 | wairoa
# Processing Record 14 of Set 12 | olafsvik
# Processing Record 15 of Set 12 | trairi
# Processing Record 16 of Set 12 | hobyo
# Processing Record 17 of Set 12 | huejuquilla el alto
# Processing Record 18 of Set 12 | gua musang
# Processing Record 19 of Set 12 | kauhajoki
# Processing Record 20 of Set 12 | kajaani
# Processing Record 21 of Set 12 | silvania
# Processing Record 22 of Set 12 | sijunjung
# Processing Record 23 of Set 12 | nantucket
# Processing Record 24 of Set 12 | ahuimanu
# Processing Record 25 of Set 12 | contamana
# Processing Record 26 of Set 12 | kyenjojo
# Processing Record 27 of Set 12 | garh maharaja
# Processing Record 28 of Set 12 | sigli
# Processing Record 29 of Set 12 | gat
# Processing Record 30 of Set 12 | gamba
# Processing Record 31 of Set 12 | verkhoyansk
# Processing Record 32 of Set 12 | mahabad
# Processing Record 33 of Set 12 | pandan
# Processing Record 34 of Set 12 | limulunga
# Processing Record 35 of Set 12 | shetpe
# Processing Record 36 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 12 | san rafael
# Processing Record 38 of Set 12 | shenzhen
# Processing Record 39 of Set 12 | ambilobe
# Processing Record 40 of Set 12 | rincon de tamayo
# Processing Record 41 of Set 12 | waingapu
# Processing Record 42 of Set 12 | merauke
# Processing Record 43 of Set 12 | agarak
# Processing Record 44 of Set 12 | okhotsk
# Processing Record 45 of Set 12 | bastos
# Processing Record 46 of Set 12 | darasun
# Processing Record 47 of Set 12 | coria
# Processing Record 48 of Set 12 | oistins
# Processing Record 49 of Set 12 | huanuni
# Processing Record 50 of Set 12 | san miguel ixtahuacan
# Processing Record 1 of Set 13 | blackwater
# Processing Record 2 of Set 13 | suihua
# Processing Record 3 of Set 13 | peleduy
# Processing Record 4 of Set 13 | henzada
# City not found. Skipping...
# Processing Record 5 of Set 13 | mednogorsk
# Processing Record 6 of Set 13 | carauari
# Processing Record 7 of Set 13 | ayan
# Processing Record 8 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 13 | xingyi
# Processing Record 10 of Set 13 | bac can
# City not found. Skipping...
# Processing Record 11 of Set 13 | kautokeino
# Processing Record 12 of Set 13 | ucar
# Processing Record 13 of Set 13 | coihaique
# Processing Record 14 of Set 13 | valparaiso
# Processing Record 15 of Set 13 | bogorodskoye
# Processing Record 16 of Set 13 | nishihara
# Processing Record 17 of Set 13 | am timan
# Processing Record 18 of Set 13 | sokoni
# Processing Record 19 of Set 13 | souillac
# Processing Record 20 of Set 13 | rosarito
# Processing Record 21 of Set 13 | mogapi
# Processing Record 22 of Set 13 | zonguldak
# Processing Record 23 of Set 13 | christchurch
# Processing Record 24 of Set 13 | linkenheim-hochstetten
# Processing Record 25 of Set 13 | iskateley
# Processing Record 26 of Set 13 | venice
# Processing Record 27 of Set 13 | graciano sanchez
# Processing Record 28 of Set 13 | ahipara
# Processing Record 29 of Set 13 | coyuca
# City not found. Skipping...
# Processing Record 30 of Set 13 | whitehorse
# Processing Record 31 of Set 13 | paita
# Processing Record 32 of Set 13 | aklavik
# Processing Record 33 of Set 13 | zyryanskoye
# Processing Record 34 of Set 13 | lamar
# Processing Record 35 of Set 13 | norman wells
# Processing Record 36 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 13 | coos bay
# Processing Record 38 of Set 13 | la grande
# Processing Record 39 of Set 13 | evensk
# Processing Record 40 of Set 13 | lahuachaca
# Processing Record 41 of Set 13 | ust-nera
# Processing Record 42 of Set 13 | otavi
# Processing Record 43 of Set 13 | magdagachi
# Processing Record 44 of Set 13 | san cristobal
# Processing Record 45 of Set 13 | plettenberg bay
# Processing Record 46 of Set 13 | skibbereen
# Processing Record 47 of Set 13 | palma di montechiaro
# Processing Record 48 of Set 13 | itarema
# Processing Record 49 of Set 13 | mpanda
# Processing Record 50 of Set 13 | crestline
# Processing Record 1 of Set 14 | el porvenir
# Processing Record 2 of Set 14 | guasdualito
# Processing Record 3 of Set 14 | ponta do sol
# Processing Record 4 of Set 14 | nosy varika
# Processing Record 5 of Set 14 | acarau
# Processing Record 6 of Set 14 | ulladulla
# Processing Record 7 of Set 14 | vila
# Processing Record 8 of Set 14 | sciacca
# Processing Record 9 of Set 14 | south portland
# Processing Record 10 of Set 14 | marsa matruh
# Processing Record 11 of Set 14 | matay
# Processing Record 12 of Set 14 | usinsk
# Processing Record 13 of Set 14 | lazarev
# Processing Record 14 of Set 14 | teeli
# Processing Record 15 of Set 14 | patrocinio
# Processing Record 16 of Set 14 | lubao
# Processing Record 17 of Set 14 | zhigansk
# Processing Record 18 of Set 14 | scottsbluff
# Processing Record 19 of Set 14 | ipora
# Processing Record 20 of Set 14 | ambon
# Processing Record 21 of Set 14 | kushima
# Processing Record 22 of Set 14 | nizhniy kuranakh
# Processing Record 23 of Set 14 | mandalgovi
# Processing Record 24 of Set 14 | brunico
# Processing Record 25 of Set 14 | voi
# Processing Record 26 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 27 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 28 of Set 14 | pindamonhangaba
# Processing Record 29 of Set 14 | lagoa
# Processing Record 30 of Set 14 | palma
# Processing Record 31 of Set 14 | takoradi
# Processing Record 32 of Set 14 | machali
# Processing Record 33 of Set 14 | taman
# Processing Record 34 of Set 14 | srandakan
# Processing Record 35 of Set 14 | mount pleasant
# Processing Record 36 of Set 14 | mocoa
# Processing Record 37 of Set 14 | umm bab
# Processing Record 38 of Set 14 | amapa
# Processing Record 39 of Set 14 | lufkin
# Processing Record 40 of Set 14 | anadyr
# Processing Record 41 of Set 14 | saskylakh
# Processing Record 42 of Set 14 | skage
# City not found. Skipping...
# Processing Record 43 of Set 14 | nagato
# Processing Record 44 of Set 14 | biloela
# Processing Record 45 of Set 14 | skjervoy
# Processing Record 46 of Set 14 | krasnousolskiy
# City not found. Skipping...
# Processing Record 47 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 48 of Set 14 | san juan
# Processing Record 49 of Set 14 | tirau
# Processing Record 50 of Set 14 | beringovskiy
# Processing Record 1 of Set 15 | fare
# Processing Record 2 of Set 15 | espanola
# Processing Record 3 of Set 15 | lund
# Processing Record 4 of Set 15 | bubaque
# Processing Record 5 of Set 15 | pathein
# Processing Record 6 of Set 15 | adrar
# Processing Record 7 of Set 15 | zhicheng
# Processing Record 8 of Set 15 | portales
# Processing Record 9 of Set 15 | bucerias
# Processing Record 10 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 11 of Set 15 | pareora
# Processing Record 12 of Set 15 | marsh harbour
# Processing Record 13 of Set 15 | namatanai
# Processing Record 14 of Set 15 | chicama
# Processing Record 15 of Set 15 | cap malheureux
# Processing Record 16 of Set 15 | cockburn town
# Processing Record 17 of Set 15 | dawlatabad
# Processing Record 18 of Set 15 | altagracia de orituco
# Processing Record 19 of Set 15 | lebanon
# Processing Record 20 of Set 15 | valdosta
# Processing Record 21 of Set 15 | chama
# Processing Record 22 of Set 15 | felidhoo
# City not found. Skipping...
# Processing Record 23 of Set 15 | rawson
# Processing Record 24 of Set 15 | milyutinskaya
# Processing Record 25 of Set 15 | mhango
# Processing Record 26 of Set 15 | iralaya
# Processing Record 27 of Set 15 | itacoatiara
# Processing Record 28 of Set 15 | mentok
# City not found. Skipping...
# Processing Record 29 of Set 15 | somova
# Processing Record 30 of Set 15 | lamu
# Processing Record 31 of Set 15 | zhuhai
# Processing Record 32 of Set 15 | ganta
# Processing Record 33 of Set 15 | magadan
# Processing Record 34 of Set 15 | sulurpeta
# City not found. Skipping...
# Processing Record 35 of Set 15 | wamba
# Processing Record 36 of Set 15 | kargasok
# Processing Record 37 of Set 15 | gizo
# Processing Record 38 of Set 15 | grevenbroich
# Processing Record 39 of Set 15 | hamilton
# Processing Record 40 of Set 15 | kabompo
# Processing Record 41 of Set 15 | vilhena
# Processing Record 42 of Set 15 | tual
# Processing Record 43 of Set 15 | coruripe
# Processing Record 44 of Set 15 | ternate
# Processing Record 45 of Set 15 | zaragoza
# Processing Record 46 of Set 15 | abu dhabi
# Processing Record 47 of Set 15 | pringsewu
# Processing Record 48 of Set 15 | esmeraldas
# Processing Record 49 of Set 15 | bougouni
# Processing Record 50 of Set 15 | wanning
# Processing Record 1 of Set 16 | uvarovo
# Processing Record 2 of Set 16 | dondo
# Processing Record 3 of Set 16 | januaria
# Processing Record 4 of Set 16 | khonuu
# City not found. Skipping...
# Processing Record 5 of Set 16 | alakurtti
# Processing Record 6 of Set 16 | ayios matthaios
# City not found. Skipping...
# Processing Record 7 of Set 16 | ye
# City not found. Skipping...
# Processing Record 8 of Set 16 | sungaipenuh
# Processing Record 9 of Set 16 | totness
# Processing Record 10 of Set 16 | kenai
# Processing Record 11 of Set 16 | aitape
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 687

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Khatanga  71.9667  102.5000     20.34        97         100
# 1          Cape Town -33.9258   18.4232     73.09        58           0
# 2         Port Hardy  50.6996 -127.4199     53.55        91          77
# 3              Diffa  13.3154   12.6113     94.44        15           1
# 4          Hithadhoo  -0.6000   73.0833     81.88        70          97
# 5            Cayenne   4.9333  -52.3333     89.64        55           0
# 6               Aksu  41.1231   80.2644     60.42        20         100
# 7          Soc Trang   9.6033  105.9800     75.96        89          60
# 8    Arraial Do Cabo -22.9661  -42.0278     84.16        61           0
# 9  Sao Joao Da Barra -21.6403  -41.0511     82.49        74          90
#
#    Wind Speed Country Current Description
# 0        4.14      RU     overcast clouds
# 1       10.36      ZA           clear sky
# 2        5.41      CA       broken clouds
# 3       12.75      NE           clear sky
# 4        9.44      MV     overcast clouds
# 5        9.22      GF           clear sky
# 6        2.28      CN     overcast clouds
# 7        5.75      VN       broken clouds
# 8       20.71      BR           clear sky
# 9       16.31      BR     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
reorder_columns = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[reorder_columns]

# Display sample data
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Khatanga      RU  71.9667  102.5000     20.34        97
# 1          Cape Town      ZA -33.9258   18.4232     73.09        58
# 2         Port Hardy      CA  50.6996 -127.4199     53.55        91
# 3              Diffa      NE  13.3154   12.6113     94.44        15
# 4          Hithadhoo      MV  -0.6000   73.0833     81.88        70
# 5            Cayenne      GF   4.9333  -52.3333     89.64        55
# 6               Aksu      CN  41.1231   80.2644     60.42        20
# 7          Soc Trang      VN   9.6033  105.9800     75.96        89
# 8    Arraial Do Cabo      BR -22.9661  -42.0278     84.16        61
# 9  Sao Joao Da Barra      BR -21.6403  -41.0511     82.49        74
#
#    Cloudiness  Wind Speed Current Description
# 0         100        4.14     overcast clouds
# 1           0       10.36           clear sky
# 2          77        5.41       broken clouds
# 3           1       12.75           clear sky
# 4          97        9.44     overcast clouds
# 5           0        9.22           clear sky
# 6         100        2.28     overcast clouds
# 7          60        5.75       broken clouds
# 8           0       20.71           clear sky
# 9          90       16.31     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = 'weather_database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file)
